# %%
# %pip install easyocr pandas pillow pix2tex
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in c:\users\user\appdata\roaming\python\python311\site-packages (2.2.2)
# Requirement already satisfied: pillow in c:\users\user\appdata\roaming\python\python311\site-packages (10.3.0)
# Requirement already satisfied: pix2tex in c:\users\user\appdata\roaming\python\python311\site-packages (0.1.4)
# Requirement already satisfied: torch in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (2.10.0)
# Requirement already satisfied: torchvision>=0.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (0.25.0)
# Requirement already satisfied: opencv-python-headless in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (4.13.0.92)
# Requirement already satisfied: scipy in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (1.17.0)
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (2.2.6)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.26.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.7-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: PyYAML in c:\users\user\appdata\roaming\python\python311\site-packages (from easyocr) (6.0.2)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.1.2-cp311-cp311-win_amd64.whl.metadata (7.1 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.4.0-cp311-cp311-win_amd64.whl.metadata (8.8 kB)
# Collecting ninja (from easyocr)
#   Using cached ninja-1.13.0-py3-none-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\roaming\python\python311\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tqdm>=4.47.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (4.67.1)
# Requirement already satisfied: munch>=2.5.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (4.0.0)
# Requirement already satisfied: requests>=2.22.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (2.31.0)
# Requirement already satisfied: einops>=0.3.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (0.8.2)
# Requirement already satisfied: x-transformers==0.15.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (0.15.0)
# Requirement already satisfied: transformers>=4.18.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (5.1.0)
# Requirement already satisfied: tokenizers>=0.13.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (0.22.2)
# Requirement already satisfied: timm==0.5.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (0.5.4)
# Requirement already satisfied: albumentations<=1.4.24,>=0.5.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (1.4.24)
# Requirement already satisfied: pyreadline3>=3.4.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from pix2tex) (3.5.4)
# Requirement already satisfied: entmax in c:\users\user\appdata\roaming\python\python311\site-packages (from x-transformers==0.15.0->pix2tex) (1.3)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex) (2.10.3)
# Requirement already satisfied: albucore==0.0.23 in c:\users\user\appdata\roaming\python\python311\site-packages (from albumentations<=1.4.24,>=0.5.2->pix2tex) (0.0.23)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from albucore==0.0.23->albumentations<=1.4.24,>=0.5.2->pix2tex) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from albucore==0.0.23->albumentations<=1.4.24,>=0.5.2->pix2tex) (6.5.12)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations<=1.4.24,>=0.5.2->pix2tex) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations<=1.4.24,>=0.5.2->pix2tex) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from pydantic>=2.9.2->albumentations<=1.4.24,>=0.5.2->pix2tex) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->pix2tex) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->pix2tex) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->pix2tex) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python311\site-packages (from requests>=2.22.0->pix2tex) (2024.2.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\user\appdata\roaming\python\python311\site-packages (from tokenizers>=0.13.0->pix2tex) (1.4.1)
# Requirement already satisfied: filelock in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (2024.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (0.25.2)
# Requirement already satisfied: packaging>=20.9 in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (24.0)
# Requirement already satisfied: shellingham in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\user\appdata\roaming\python\python311\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (0.21.2)
# Requirement already satisfied: anyio in c:\users\user\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (4.2.0)
# Requirement already satisfied: httpcore==1.* in c:\users\user\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (1.0.2)
# Requirement already satisfied: sniffio in c:\users\user\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\appdata\roaming\python\python311\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (0.14.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from torch->easyocr) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\user\appdata\roaming\python\python311\site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\roaming\python\python311\site-packages (from torch->easyocr) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from sympy>=1.13.3->torch->easyocr) (1.3.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python311\site-packages (from tqdm>=4.47.0->pix2tex) (0.4.6)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\appdata\roaming\python\python311\site-packages (from transformers>=4.18.0->pix2tex) (2026.1.15)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\user\appdata\roaming\python\python311\site-packages (from transformers>=4.18.0->pix2tex) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from jinja2->torch->easyocr) (3.0.2)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->easyocr)
#   Downloading imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2026.1.28-py3-none-any.whl.metadata (30 kB)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\user\appdata\roaming\python\python311\site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (8.1.7)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\user\appdata\roaming\python\python311\site-packages (from typer-slim->huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->pix2tex) (0.0.4)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.8/2.9 MB 2.8 MB/s eta 0:00:01
#    -------------------------------- ------- 2.4/2.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.9/2.9 MB 5.6 MB/s  0:00:00
# Using cached ninja-1.13.0-py3-none-win_amd64.whl (309 kB)
# Downloading pyclipper-1.4.0-cp311-cp311-win_amd64.whl (104 kB)
# Downloading python_bidi-0.6.7-cp311-cp311-win_amd64.whl (161 kB)
# Downloading scikit_image-0.26.0-cp311-cp311-win_amd64.whl (11.9 MB)
#    ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.9 MB 8.4 MB/s eta 0:00:02
#    -------------- ------------------------- 4.2/11.9 MB 9.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.6/11.9 MB 10.1 MB/s eta 0:00:01
#    ------------------------------ --------- 9.2/11.9 MB 10.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.5/11.9 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.9/11.9 MB 10.6 MB/s  0:00:01
# Downloading imageio-2.37.2-py3-none-any.whl (317 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading tifffile-2026.1.28-py3-none-any.whl (233 kB)
# Downloading shapely-2.1.2-cp311-cp311-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 11.7 MB/s  0:00:00
# Installing collected packages: python-bidi, tifffile, Shapely, pyclipper, ninja, lazy-loader, imageio, scikit-image, easyocr
#
#    ---------------------------------------- 0/9 [python-bidi]
#    ---- ----------------------------------- 1/9 [tifffile]
#    ---- ----------------------------------- 1/9 [tifffile]
#    ---- ----------------------------------- 1/9 [tifffile]
#    ---- ----------------------------------- 1/9 [tifffile]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    -------- ------------------------------- 2/9 [Shapely]
#    ---------------------- ----------------- 5/9 [lazy-loader]
#    -------------------------- ------------- 6/9 [imageio]
#    -------------------------- ------------- 6/9 [imageio]
#    -------------------------- ------------- 6/9 [imageio]
#    -------------------------- ------------- 6/9 [imageio]
#    -------------------------- ------------- 6/9 [imageio]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ------------------------------- -------- 7/9 [scikit-image]
#    ----------------------------------- ---- 8/9 [easyocr]
#    ----------------------------------- ---- 8/9 [easyocr]
#    ----------------------------------- ---- 8/9 [easyocr]
#    ----------------------------------- ---- 8/9 [easyocr]
#    ---------------------------------------- 9/9 [easyocr]
#
# Successfully installed Shapely-2.1.2 easyocr-1.7.2 imageio-2.37.2 lazy-loader-0.4 ninja-1.13.0 pyclipper-1.4.0 python-bidi-0.6.7 scikit-image-0.26.0 tifffile-2026.1.28
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from io import BytesIO
import os
import re
import pandas as pd
from PIL import Image
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML

import easyocr
from pix2tex.cli import LatexOCR

# -------------------- Load models once --------------------
# EasyOCR downloads models on first run (can take a bit the first time)
ocr_reader = easyocr.Reader(['en'], gpu=False)  # set gpu=True if you have a CUDA GPU
latex_model = LatexOCR()

# -------------------- UI Widgets --------------------
title = widgets.HTML(
    "<h2 style='margin:0'>📥 Question Image → CSV (with LaTeX)</h2>"
    "<div style='color:#888;margin-top:4px'>Upload image → extract question & choices → append to CSV.</div>"
)

upload = widgets.FileUpload(accept="image/*", multiple=False, description="Upload image")

csv_path = widgets.Text(
    value="questions.csv",
    description="CSV path:",
    style={"description_width": "80px"},
    layout=widgets.Layout(width="600px")
)

append_btn = widgets.Button(description="Append to CSV", button_style="success", icon="plus",
                            layout=widgets.Layout(width="160px", height="40px"))

clear_btn = widgets.Button(description="Clear", button_style="warning", icon="trash",
                           layout=widgets.Layout(width="120px", height="40px"))

status = widgets.HTML("<span style='color:#888'>Status: waiting…</span>")

preview_out = widgets.Output(layout=widgets.Layout(border="1px solid #333", padding="10px", width="100%"))
result_out = widgets.Output(layout=widgets.Layout(border="1px solid #333", padding="10px", width="100%"))

# -------------------- Helpers --------------------
def load_uploaded_pil_image():
    """
    VS Code ipywidgets FileUpload:
      - upload.value is a tuple of dict(s)
      - dict has key "content" which is bytes-like (often memoryview)
    """
    if not upload.value:
        return None, None
    file = upload.value[0]
    name = file.get("name", "uploaded_image")
    content = file["content"]
    img = Image.open(BytesIO(content)).convert("RGB")
    return img, name

def ocr_text_lines(pil_img):
    """
    Returns OCR lines in reading order.
    """
    import numpy as np
    arr = np.array(pil_img)
    results = ocr_reader.readtext(arr, detail=0, paragraph=False)
    # results is list[str] in reading-ish order
    lines = [r.strip() for r in results if str(r).strip()]
    return lines

def split_question_and_choices(lines):
    """
    Best-effort splitter.
    Recognizes:
      A) ... B) ... C) ... D) ...
      A. ... etc
      1) ... 2) ... 3) ... 4) ...
    Returns: (question_text, A, B, C, D)
    """
    text = "\n".join(lines)

    # Normalize some common markers
    # We'll find options by regex and split.
    patterns = [
        r'(?i)\bA[\).\:]',
        r'(?i)\bB[\).\:]',
        r'(?i)\bC[\).\:]',
        r'(?i)\bD[\).\:]',
    ]

    # If A/B/C/D markers exist, split by them
    if re.search(patterns[0], text):
        # split keeping markers
        parts = re.split(r'(?i)\b([ABCD])[\).\:]\s*', text)
        # parts: [before, 'A', afterA, 'B', afterB, 'C', afterC, 'D', afterD, ...]
        question = parts[0].strip()
        opts = {"A":"", "B":"", "C":"", "D":""}
        i = 1
        while i + 1 < len(parts):
            key = parts[i].upper().strip()
            val = parts[i+1].strip()
            if key in opts:
                # Clean trailing next markers already handled by split
                opts[key] = val
            i += 2
        return question, opts["A"], opts["B"], opts["C"], opts["D"]

    # If 1/2/3/4 markers exist, map them to A-D
    if re.search(r'\b1[\).\:]', text):
        parts = re.split(r'\b([1-4])[\).\:]\s*', text)
        question = parts[0].strip()
        opts = {"1":"", "2":"", "3":"", "4":""}
        i = 1
        while i + 1 < len(parts):
            key = parts[i].strip()
            val = parts[i+1].strip()
            if key in opts:
                opts[key] = val
            i += 2
        return question, opts["1"], opts["2"], opts["3"], opts["4"]

    # Fallback: no markers found
    # We’ll try: first ~1/2 is question, rest empty.
    # (You can improve this later based on your screenshots format.)
    question = " ".join(lines).strip()
    return question, "", "", "", ""

def pix2tex_latex(pil_img):
    """
    Best-effort LaTeX from the image.
    If the image is a full multiple-choice screenshot, this may not be perfect.
    Still useful as a 'math latex guess' column.
    """
    try:
        return latex_model(pil_img)
    except Exception as e:
        return f"LATEX_ERROR: {repr(e)}"

def append_row_to_csv(csv_file, row_dict):
    os.makedirs(os.path.dirname(csv_file) or ".", exist_ok=True)
    df_new = pd.DataFrame([row_dict])

    if os.path.exists(csv_file) and os.path.getsize(csv_file) > 0:
        # append without header
        df_new.to_csv(csv_file, mode="a", header=False, index=False, encoding="utf-8")
    else:
        df_new.to_csv(csv_file, mode="w", header=True, index=False, encoding="utf-8")

# -------------------- Actions --------------------
def on_append(_):
    with result_out:
        clear_output()
    with preview_out:
        clear_output()

    img, name = load_uploaded_pil_image()
    if img is None:
        status.value = "<span style='color:#d29922'>Status: upload an image first.</span>"
        return

    status.value = "<span style='color:#58a6ff'>Status: extracting text…</span>"
    with preview_out:
        display(img)

    lines = ocr_text_lines(img)
    question_text, A, B, C, D = split_question_and_choices(lines)

    status.value = "<span style='color:#58a6ff'>Status: generating LaTeX (best-effort)…</span>"
    question_latex = pix2tex_latex(img)

    row = {
        "question_text": question_text,
        "question_latex": question_latex,
        "A": A,
        "B": B,
        "C": C,
        "D": D,
        "source_image": name
    }

    csv_file = csv_path.value.strip()
    if not csv_file:
        status.value = "<span style='color:#f85149'>Status: CSV path is empty.</span>"
        return

    append_row_to_csv(csv_file, row)

    status.value = f"<span style='color:#3fb950'>Status: appended ✅ → {csv_file}</span>"

    with result_out:
        print("Extracted question_text:\n", question_text, "\n")
        print("Choices:")
        print("A:", A)
        print("B:", B)
        print("C:", C)
        print("D:", D)
        print("\nLaTeX (best-effort):\n", question_latex)

def on_clear(_):
    upload.value = ()
    status.value = "<span style='color:#888'>Status: waiting…</span>"
    with preview_out:
        clear_output()
    with result_out:
        clear_output()

append_btn.on_click(on_append)
clear_btn.on_click(on_clear)

# -------------------- Layout --------------------
buttons = widgets.HBox([append_btn, clear_btn], layout=widgets.Layout(gap="10px"))

ui = widgets.VBox([
    title,
    widgets.HTML("<hr style='border:0;border-top:1px solid #333;margin:10px 0'/>"),
    widgets.HBox([upload, csv_path], layout=widgets.Layout(gap="12px")),
    buttons,
    status,
    widgets.HTML("<b>Image preview</b>"),
    preview_out,
    widgets.HTML("<b>Extraction result</b>"),
    result_out
])

display(ui)
# Out:
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# VBox(children=(HTML(value="<h2 style='margin:0'>📥 Question Image → CSV (with LaTeX)</h2><div style='color:#888…
